# %%
# %pip install streamlit
# %pip install langchain-core langchain-classic
# Out:
# Requirement already satisfied: streamlit in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (1.55.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (7.0.2)
# Requirement already satisfied: click<9,>=7.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (2.4.2)
# Requirement already satisfied: packaging>=20 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (6.5.4)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.17.0)
# Requirement already satisfied: colorama in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain-core in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (1.2.17)
# Requirement already satisfied: langchain-classic in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (1.0.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (0.7.11)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-core) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.12.1)
# Requirement already satisfied: certifi in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-classic) (1.1.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install  google-genai
# Out:
# Requirement already satisfied: google-genai in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (1.68.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (4.12.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.49.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (2.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (46.0.5)
# Requirement already satisfied: certifi in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install yt_dlp
# Out:
# Requirement already satisfied: yt_dlp in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (2026.3.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U yt-dlp
# Out:
# Requirement already satisfied: yt-dlp in c:\Users\dlcksgml\miniconda3\envs\langchain-insurance\Lib\site-packages (2026.3.17)
# Note: you may need to restart the kernel to use updated packages.
